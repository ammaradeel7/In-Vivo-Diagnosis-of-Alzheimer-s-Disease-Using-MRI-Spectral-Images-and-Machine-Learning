# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install pydicom
pip install plotly
pip install scikit-image
pip install dicom
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 4.3 MB/s
# ...

# %%
import numpy as np
import dicom
import os
import matplotlib.pyplot as plt
from glob import glob
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import scipy.ndimage
from skimage import morphology
from skimage import measure
from skimage.transform import resize
from sklearn.cluster import KMeans
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.tools import FigureFactory as FF
from plotly.graph_objs import *
init_notebook_mode(connected=True)

# %%
data_path = "/content/drive/MyDrive/CN.zip (Unzipped Files) (1)/ADNI"
output_path = working_path = "/content/drive/MyDrive/CN.zip (Unzipped Files) (1)/ADNI"
g = glob(data_path + '/*.dcm')

# Print out the first 5 file names to verify we're in the right folder.
print ("Total of %d DICOM images.\nFirst 5 filenames:" % len(g))

# %%
import glob 
import shutil

    
destination_path = "/content/drive/MyDrive/results"
pattern = "/content/drive/MyDrive/CN.zip (Unzipped Files) (1)/ADNI/*/*/*/*/*"  
for img in glob.glob(pattern):
    shutil.copy(img, destination_path)

# %%
from glob import glob

# %%
data_path = "/content/drive/MyDrive/results"
output_path = working_path = "/content/drive/MyDrive/working"
g = glob(data_path + '/*.dcm')

# Print out the first 5 file names to verify we're in the right folder.
print ("Total of %d DICOM images.\nFirst 5 filenames:" % len(g))
print (g[:5])
# Out:
# Total of 1019 DICOM images.
# First 5 filenames:
# ['/content/drive/MyDrive/results/ADNI_027_S_0074_MR_3-plane_localizer__br_raw_20150218114651740_5_S249015_I473730.dcm', '/content/drive/MyDrive/results/ADNI_027_S_0074_MR_3-plane_localizer__br_raw_20150218114648357_2_S249015_I473730.dcm', '/content/drive/MyDrive/results/ADNI_027_S_0074_MR_3-plane_localizer__br_raw_20150218114648660_1_S249015_I473730.dcm', '/content/drive/MyDrive/results/ADNI_027_S_0074_MR_3-plane_localizer__br_raw_20150218114649477_4_S249015_I473730.dcm', '/content/drive/MyDrive/results/ADNI_027_S_0074_MR_3-plane_localizer__br_raw_20150218114648062_3_S249015_I473730.dcm']

# %%
import pydicom as dicom
import matplotlib.pylab as plt

# specify your image path

ds = dicom.dcmread("/content/drive/MyDrive/results/ADNI_002_S_0413_MR_3-plane_localizer__br_raw_20060502142533452_1_S13890_I14432.dcm")


plt.imshow(ds.pixel_array)

# %%
ds = dicom.dcmread("/content/drive/MyDrive/results/ADNI_002_S_0413_MR_3-plane_localizer__br_raw_20060502142537125_3_S13890_I14432.dcm")


plt.imshow(ds.pixel_array)

# %%
ds = dicom.dcmread("/content/drive/MyDrive/results/ADNI_002_S_0413_MR_3-plane_localizer__br_raw_20060502142542988_6_S13890_I14432.dcm")


plt.imshow(ds.pixel_array)

# %%
pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 5.0 MB/s
# ...

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import shutil
import pydicom as dicom
import os
import cv2
import PIL # optional

# %%
import pydicom as dicom
import os
import cv2
import PIL # optional
# make it True if you want in PNG format
PNG = False
# Specify the .dcm folder path
folder_path = "/content/drive/MyDrive/results" 
# Specify the output jpg/png folder path
jpg_folder_path = "/content/drive/MyDrive/cnjpg"
images_path = os.listdir(folder_path)
for n, image in enumerate(images_path):
    ds = dicom.dcmread(os.path.join(folder_path, image))
    pixel_array_numpy = ds.pixel_array
    if PNG == False:
        image = image.replace('.dcm', '.jpg')
    else:
        image = image.replace('.dcm', '.png')
    cv2.imwrite(os.path.join(jpg_folder_path, image), pixel_array_numpy)
    if n % 50 == 0:
        print('{} image converted'.format(n))

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
from sklearn.cluster import KMeans

# %%
data_path = "/content/drive/MyDrive/results"
output_path = working_path = "/content/drive/MyDrive/working"
files = glob(data_path + '*.jpg')

# %%
X_data = []
files = glob ("/content/drive/MyDrive/cnjpg/"+"*.jpg")
for myFile in files:
    image = cv2.imread (myFile,0)
    
    X_data.append (image)

print('X_data shape:', np.array(X_data).shape)
# Out:
# X_data shape: (183, 256, 256)

# %%
files = glob ("/content/drive/MyDrive/adjpg/"+"*.jpg")
for myFile in files:
    image = cv2.imread (myFile,0)
    
    X_data.append (image)

print('X_data shape:', np.array(X_data).shape)
# Out:
# X_data shape: (1299, 256, 256)

# %%
X_data

# %%
n =2

# %%
np.array(X_data)

# %%
X_data[0]

# %%
np.array(X_data).shape
# Out:
# (183, 256, 256)

# %%
nsamples, nx, ny = np.array(X_data).shape 
d2_train_dataset = np.array(X_data).reshape((nsamples,nx*ny))

# %%
kmeans = KMeans(n_clusters=2,init='random')
kmeans.fit(d2_train_dataset)
Z = kmeans.predict(d2_train_dataset)

# %%
Z
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
plt.hist(Z);
plt.show()

# %%
Z
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
Z[3]
# Out:
# 0

# %%
Z[-20]
# Out:
# 1

# %% [markdown]
# Cluster 1

# %%
arr = np.asarray(X_data[0])
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
arr = np.asarray(X_data[1])
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
arr = np.asarray(X_data[2])
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
arr = np.asarray(X_data[3])
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# Cluster 2

# %%
arr = np.asarray(X_data[-20])
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
arr = np.asarray(X_data[-5])
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
arr = np.asarray(X_data[-4])
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
arr = np.asarray(X_data[-1])
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
arr = np.asarray(X_data[-2])
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
arr = np.asarray(X_data[-3])
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()
